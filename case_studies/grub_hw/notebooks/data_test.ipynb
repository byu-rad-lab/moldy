# %%
import numpy as np
# input_data = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/train_inputdata.npy")
# input_validation = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/validation_inputdata.npy")
# output_validation = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/validation_outputdata.npy")
# output_train = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/train_outputdata.npy")

input_data = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/good_data/max_normalization/smooth/train_inputdata.npy")
input_validation = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/good_data/max_normalization/smooth/validation_inputdata.npy")
output_validation = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/good_data/max_normalization/smooth/validation_outputdata.npy")
output_train = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/grub_hw/data/good_data/max_normalization/smooth/train_outputdata.npy")

print("input_data shape: ", input_data.shape)
print("input_validation shape: ", input_validation.shape)
print("output_validation shape: ", output_validation.shape)
print("output_train shape: ", output_train.shape)
# Out:
# input_data shape:  (274259, 12)
# input_validation shape:  (68565, 12)
# output_validation shape:  (68565, 8)
# output_train shape:  (274259, 8)

# %%
print("Training Inputs")
print(f"p0: min: {np.min(input_data[:,0])}, max: {np.max(input_data[:,0])}, mean: {np.mean(input_data[:,0])}, std: {np.std(input_data[:,0])}")
print(f"p1: min: {np.min(input_data[:,1])}, max: {np.max(input_data[:,1])}, mean: {np.mean(input_data[:,1])}, std: {np.std(input_data[:,1])}")
print(f"p2: min: {np.min(input_data[:,2])}, max: {np.max(input_data[:,2])}, mean: {np.mean(input_data[:,2])}, std: {np.std(input_data[:,2])}")
print(f"p3: min: {np.min(input_data[:,3])}, max: {np.max(input_data[:,3])}, mean: {np.mean(input_data[:,3])}, std: {np.std(input_data[:,3])}")

print(f"u0_dot: min: {np.min(input_data[:,4])}, max: {np.max(input_data[:,4])}, mean: {np.mean(input_data[:,4])}, std: {np.std(input_data[:,4])}")
print(f"v0_dot: min: {np.min(input_data[:,5])}, max: {np.max(input_data[:,5])}, mean: {np.mean(input_data[:,5])}, std: {np.std(input_data[:,5])}")

print(f"u0: min: {np.min(input_data[:,6])}, max: {np.max(input_data[:,6])}, mean: {np.mean(input_data[:,6])}, std: {np.std(input_data[:,6])}")
print(f"v0: min: {np.min(input_data[:,7])}, max: {np.max(input_data[:,7])}, mean: {np.mean(input_data[:,7])}, std: {np.std(input_data[:,7])}")
# Out:
# Training Inputs
# p0: min: 0.0018363167764618993, max: 0.9750842452049255, mean: 0.4981876313686371, std: 0.2626091241836548
# p1: min: 0.007957372814416885, max: 1.0056895017623901, mean: 0.513867199420929, std: 0.27231350541114807
# p2: min: 0.004896844737231731, max: 1.0148710012435913, mean: 0.5141780972480774, std: 0.2721915543079376
# p3: min: -0.004284739028662443, max: 0.9934473633766174, mean: 0.4847843647003174, std: 0.26614367961883545
# u0_dot: min: -0.1794740855693817, max: 0.17949427664279938, mean: 0.002555424813181162, std: 0.03289458528161049
# v0_dot: min: -0.16712874174118042, max: 0.16724860668182373, mean: -0.0022084128577262163, std: 0.031989049166440964
# u0: min: -0.9582021236419678, max: 0.9833031892776489, mean: 0.0007477639010176063, std: 0.5714895725250244
# v0: min: -1.009299874305725, max: 1.02924382686615, mean: 0.07454126328229904, std: 0.6121132969856262

# %%
output1 = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/baloo_sim/data/good_data/original_data/train_inputdata.npy")
output2 = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/baloo_sim/data/train_inputdata.npy")
output3 = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/baloo_sim/data/good_data/sys_id_data/train_inputdata.npy")

# %%
import numpy as np

output1 = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/baloo_sim/data/good_data/original_data/output_max.npy")
output2 = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/baloo_sim/data/output_max.npy")
output3 = np.load("/home/daniel/catkin_ws/src/moldy/case_studies/baloo_sim/data/good_data/sys_id_data/output_max.npy")

# %%
print("Output 1")
print(output1)
print("Output 2")
print(output2)
print("Output 3")
print(output3)
# Out:
# Output 1
# [14.78698225 14.71153846 14.40975799 14.71153846 13.7499131  13.89030612
#  13.32908163 13.82015306  3.52932006  3.51623584  3.45690815  3.54743631
#   2.67202747  1.73058622  8.28782256  9.27061738 10.01415956  7.72346391
#   0.05984937  0.04908473  0.11443573  0.12414631  0.15338763  0.14458531]
# Output 2
# [9.628125   9.6775     9.430625   9.57875    9.529375   9.52936979
#  9.6775     9.726875   6.51194312 6.47821441 6.21443694 6.04916667
#  1.06793253 1.2054981  1.31494752 0.88919401 5.45344044 8.12452342
#  0.04408405 0.04346943 0.04272904 0.04215573 0.06712553 0.10183337]
# Output 3
# [9.628125   9.6775     9.430625   9.57875    9.529375   9.52936979
#  9.6775     9.726875   6.51194312 6.47821441 6.21443694 6.04916667
#  1.06793253 1.2054981  1.31494752 0.88919401 5.45344044 8.12452342
#  0.04408405 0.04346943 0.04272904 0.04215573 0.06712553 0.10183337]

# %%
# plot the joint angles and velocities for the first 1000 samples
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(input_data[:30000,:2])
plt.plot(input_data[:30000,8])
plt.plot(input_data[:30000,9])

plt.legend(["P1", "P2", "PC1", "PC2"])
plt.xlabel("Sample")
plt.ylabel("Normalize Pressured")
plt.show()

# %%
# plot the joint angles and velocities for the first 1000 samples
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(input_data[:30000,2:4])
plt.plot(input_data[:30000,10])
plt.plot(input_data[:30000,11])

plt.legend(["P3", "P4", "PC3", "PC4"])
plt.xlabel("Sample")
plt.ylabel("Normalize Pressured")
plt.show()

# %%
# %matplotlib widget
# plot the joint angles and velocities for the first 1000 samples
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
# plt.plot(input_data[:1000,4])
plt.plot(input_data[:30000,4])
plt.plot(input_data[:30000,6])
plt.plot(output_train[:30000,6])
plt.legend(["Udot", "U", "Output U"])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
# plot the joint angles and velocities for the first 1000 samples
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
# plt.plot(input_data[:1000,4])
plt.plot(input_data[:10000,5])
plt.plot(input_data[:10000,7])
plt.legend(["Udot", "U"])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
